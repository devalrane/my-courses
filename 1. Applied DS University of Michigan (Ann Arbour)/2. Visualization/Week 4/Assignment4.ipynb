# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **religious events or traditions** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **religious events or traditions**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **religious events or traditions**?  For this category you might consider calendar events, demographic data about religion in the region and neighboring regions, participation in religious events, or how religious events relate to political events, social movements, or historical events.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
'''import bs4 as bs
import pickle
import requests

URL = "https://en.wikipedia.org/wiki/List_of_Manchester_United_F.C._seasons"

import time

resp = ''
while resp == '':
    try:
        resp = requests.get(URL)
        break
    except:
        print("Connection refused by the server..")
        print("Let me sleep for 5 seconds")
        print("ZZzzzz...")
        time.sleep(5)
        print("Was a nice sleep, now let me continue...")
        continue

#resp = requests.get(URL)
soup = bs.BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})

'''
# Out:
# 'import bs4 as bs\nimport pickle\nimport requests\n\nURL = "https://en.wikipedia.org/wiki/List_of_Manchester_United_F.C._seasons"\n\nimport time\n\nresp = \'\'\nwhile resp == \'\':\n    try:\n        resp = requests.get(URL)\n        break\n    except:\n        print("Connection refused by the server..")\n        print("Let me sleep for 5 seconds")\n        print("ZZzzzz...")\n        time.sleep(5)\n        print("Was a nice sleep, now let me continue...")\n        continue\n\n#resp = requests.get(URL)\nsoup = bs.BeautifulSoup(resp.text, \'lxml\')\ntable = soup.find(\'table\', {\'class\': \'wikitable sortable\'})\n\n'

# %%
# Wikipedia wasnt responding to requests sent from my IP. So I converted using an online source: https://wikitable2csv.ggor.de/

# %%
urls={
    'arsenal': 'https://drive.google.com/open?id=14ZEcUDWh_w9Oarz282cEAtsMRq1jpIej',
    'chelsea':'https://drive.google.com/open?id=1tMNZ00GFquw48y8A7jrKjyJxd_On4XFR',
    'city': 'https://drive.google.com/open?id=1MhlrKEnc0foxLDvVLvlnicqNhDTe3T9s',
    'liverpool':'https://drive.google.com/open?id=1lIfJV7RKA06YR4gHi25pzlQG73k6pUBr',
    'united':'https://drive.google.com/open?id=19CI3nk5Qk8vWS-14M_oipGCEr2IOfxt2'
}
# if anyone wants to download the CSV files, use above links

# %%
import pandas as pd
import numpy as np

arsenal = pd.read_csv('arsenal.csv')
chelsea = pd.read_csv('chelsea.csv')
city = pd.read_csv('city.csv')
liverpool = pd.read_csv('liverpool.csv')
united = pd.read_csv('united.csv')

# %%
dfs = [arsenal, chelsea, city, liverpool, united]

# %%
arsenal.head()
# Out:
#     Season    Division           P           W           D           L  \
# 0   Season  League[58]  League[58]  League[58]  League[58]  League[58]
# 1  1886-87           -           -           -           -           -
# 2  1887-88           -           -           -           -           -
# 3  1888-89           -           -           -           -           -
# 4  1889-90           -           -           -           -           -
#
#             F           A         Pts         Pos  FA Cup[56][d]  \
# 0  League[58]  League[58]  League[58]  League[58]  FA Cup[56][d]
# 1           -           -           -           -              -
# 2           -           -           -           -              -
# 3           -           -           -           -              -
# 4           -           -           -           -            QR4
#
#    LeagueCup[57]  CommunityShield[57]  \
# 0  LeagueCup[57]  CommunityShield[57]
# 1              -                    -
# ...

# %%
arsenal.drop(0,inplace=True)

# %%
city.columns = city.iloc[0]

city.drop(0,inplace=True)

city.head()
# Out:
# 0   Season Division (Tier)   P   W  D   L   F   A Pts     Pos  \
# 1  1891-92            Alln  22   6  6  10  39  51  18     8th
# 2  1892-93       Div 2 (2)  22   9  3  10  45  40  21     5th
# 3  1893-94       Div 2 (2)  28   8  2  18  47  71  18    13th
# 4  1894-95       Div 2 (2)  30  14  3  13  82  72  31     9th
# 5  1895-96       Div 2 (2)  30  21  4   5  63  38  46  2nd[C]
#
# 0            FA Cup League Cup Europe / Other Europe / Other   Top scorer[A]  \
# 1                QR        NaN            NaN            NaN     Hugh Morris
# 2                QR        NaN            NaN            NaN      David Weir
# 3                QR        NaN            NaN            NaN     Hugh Morris
# 4  Did not enter[B]        NaN            NaN            NaN   Pat Finnerhan
# 5       Withdrew[D]        NaN            NaN            NaN  Billy Meredith
#
# 0 Goals
# 1    10
# 2     8
# 3     7
# 4    15
# 5    13

# %%
chelsea.head()
# Out:
#     Season    League League.1 League.2 League.3 League.4 League.5 League.6  \
# 0   Season  Division        P        W        D        L        F        A
# 1  1905-06     Div 2       38       22        9        7       90       37
# 2  1906-07   Div 2 ↑       38       26        5        7       80       34
# 3  1907-08     Div 1       38       14        8       16       53       62
# 4  1908-09     Div 1       38       14        9       15       56       61
#
#   League.7 League.8          ...            EFLCup Other competitions  \
# 0      Pts      Pos          ...            EFLCup                 CS
# 1       53      3rd          ...               NaN                NaN
# 2       57      2nd          ...               NaN                NaN
# 3       36     13th          ...               NaN                NaN
# 4       37     11th          ...               NaN                NaN
#
#   Other competitions.1 Other competitions.2 Other competitions.3  \
# ...

# %%
chelsea.columns = chelsea.iloc[0]
chelsea.drop(0,inplace=True)
chelsea.head()
# Out:
# 0   Season Division   P   W  D   L   F   A Pts   Pos  ...  EFLCup   CS   CL  \
# 1  1905-06    Div 2  38  22  9   7  90  37  53   3rd  ...     NaN  NaN  NaN
# 2  1906-07  Div 2 ↑  38  26  5   7  80  34  57   2nd  ...     NaN  NaN  NaN
# 3  1907-08    Div 1  38  14  8  16  53  62  36  13th  ...     NaN  NaN  NaN
# 4  1908-09    Div 1  38  14  9  15  56  61  37  11th  ...     NaN  NaN  NaN
# 5  1909-10  Div 1 ↓  38  11  7  20  47  70  29  19th  ...     NaN  NaN  NaN
#
# 0   EL   CW   SC  CWC   FM                          Name Goals
# 1  NaN  NaN  NaN  NaN  NaN  Frank PearsonJimmy Windridge    18
# 2  NaN  NaN  NaN  NaN  NaN                George Hilsdon    27
# 3  NaN  NaN  NaN  NaN  NaN                George Hilsdon    30
# 4  NaN  NaN  NaN  NaN  NaN                George Hilsdon    27
# 5  NaN  NaN  NaN  NaN  NaN               Jimmy Windridge     6
#
# [5 rows x 21 columns]

# %%
liverpool.head()
# Out:
#     Season        League League.1 League.2 League.3 League.4 League.5  \
# 0   Season      Division        P        W        D        L        F
# 1  1892-93       Lancs ↑       22       17        2        3       66
# 2  1893-94  Division 2 ↑       28       22        6        0       77
# 3  1894-95  Division 1 ↓       30        7        8       15       51
# 4  1895-96  Division 2 ↑       30       22        2        6      106
#
#   League.6 League.7 League.8  FA Cup  EFL Cup  Comm. Shield  CL  EL  CWC  \
# 0        A      Pts      Pos  FA Cup  EFL Cup  Comm. Shield  CL  EL  CWC
# 1       19       36      1st     QR3        —             —   —   —    —
# 2       18       50   1st[C]      R3        —             —   —   —    —
# 3       70       22  16th[D]      R2        —             —   —   —    —
# 4       32       46   1st[E]      R2        —             —   —   —    —
#
#    Super Cup  Club World Cup       Top scorer Top scorer.1
# ...

# %%
liverpool.columns = liverpool.iloc[0]
liverpool.drop(0,inplace=True)
liverpool.head()
# Out:
# 0   Season      Division   P   W  D   L    F   A Pts      Pos FA Cup EFL Cup  \
# 1  1892-93       Lancs ↑  22  17  2   3   66  19  36      1st    QR3       —
# 2  1893-94  Division 2 ↑  28  22  6   0   77  18  50   1st[C]     R3       —
# 3  1894-95  Division 1 ↓  30   7  8  15   51  70  22  16th[D]     R2       —
# 4  1895-96  Division 2 ↑  30  22  2   6  106  32  46   1st[E]     R2       —
# 5  1896-97    Division 1  30  12  9   9   46  38  33      5th     SF       —
#
# 0 Comm. Shield CL EL CWC Super Cup Club World Cup             Name Goals
# 1            —  —  —   —         —              —      John Miller    25
# 2            —  —  —   —         —              —      James Stott    14
# 3            —  —  —   —         —              —  Thomas Bradshaw    18
# 4            —  —  —   —         —              —     George Allan    29
# 5            —  —  —   —         —              —     George Allan    18

# %%
united.head()
# Out:
#        Season     Division       P       W       D       L       F       A  \
# 0      Season       League  League  League  League  League  League  League
# 1     1886-87       n/a[8]     n/a     n/a     n/a     n/a     n/a     n/a
# 2  1888-89[9]  Combination      12       8       2       2      27      13
# 3     1889-90     Alliance      22       9       2      11      40      45
# 4     1890-91     Alliance      22       7       3      12      37      55
#
#       Pts     Pos  FA Cup  LeagueCup  CommunityShield  UEFAFIFA  \
# 0  League  League  FA Cup  LeagueCup  CommunityShield  UEFAFIFA
# 1     n/a     n/a      R1        NaN              NaN       NaN
# 2      18  n/a[9]     n/a        NaN              NaN       NaN
# 3      20     8th      R1        NaN              NaN       NaN
# 4      17     9th     QR2        NaN              NaN       NaN
#
#                         Name              Goals
# 0          Top goalscorer[7]  Top goalscorer[7]
# ...

# %%
united.drop(0,inplace=True)
united.head()
# Out:
#        Season     Division    P    W    D    L    F    A  Pts      Pos FA Cup  \
# 1     1886-87       n/a[8]  n/a  n/a  n/a  n/a  n/a  n/a  n/a      n/a     R1
# 2  1888-89[9]  Combination   12    8    2    2   27   13   18   n/a[9]    n/a
# 3     1889-90     Alliance   22    9    2   11   40   45   20      8th     R1
# 4     1890-91     Alliance   22    7    3   12   37   55   17      9th    QR2
# 5     1891-92     Alliance   22   12    7    3   69   33   31  2nd[10]    QR4
#
#   LeagueCup CommunityShield UEFAFIFA                       Name Goals
# 1       NaN             NaN      NaN               Jack Doughty     2
# 2       NaN             NaN      NaN  Jack DoughtyRoger Doughty     6
# 3       NaN             NaN      NaN             Willie Stewart    10
# 4       NaN             NaN      NaN                 Bob Ramsay     7
# 5       NaN             NaN      NaN    Bob DonaldsonAlf Farman    20

# %%
'''

COLUMN NAMES HAVE BEEN CLEANED

'''
# Out:
# '\n\nCOLUMN NAMES HAVE BEEN CLEANED\n\n'

# %%
arsenal[arsenal['Season']=='1986-87']
# Out:
#      Season Division   P   W   D   L   F   A Pts  Pos FA Cup[56][d]  \
# 94  1986-87    Div 1  42  20  10  12  58  35  70  4th            QF
#
#    LeagueCup[57] CommunityShield[57] Competition Result          Name Goals
# 94             W                   -           -      -  Martin Hayes    24

# %%
arsenal = arsenal[93:]

# %%
chelsea[chelsea['Season']=='1986-87']
# Out:
# 0    Season Division   P   W   D   L   F   A Pts   Pos  ...  EFLCup   CS   CL  \
# 74  1986-87    Div 1  42  13  13  16  53  64  52  14th  ...      R3  NaN  NaN
#
# 0    EL   CW   SC  CWC  FM         Name Goals
# 74  NaN  NaN  NaN  NaN  R4  Kerry Dixon    12
#
# [1 rows x 21 columns]

# %%
chelsea = chelsea[73:]
chelsea.head()
# Out:
# 0    Season Division   P   W   D   L   F   A Pts   Pos  ...  EFLCup   CS   CL  \
# 74  1986-87    Div 1  42  13  13  16  53  64  52  14th  ...      R3  NaN  NaN
# 75  1987-88    Div 1  40   9  15  16  50  68  42  18th  ...      R2  NaN  NaN
# 76  1988-89    Div 2  46  29  12   5  96  50  99   0th  ...      R2  NaN  NaN
# 77  1989-90    Div 1  38  16  12  10  58  50  60   5th  ...      R2  NaN  NaN
# 78  1990-91    Div 1  38  13  10  15  58  69  49  11th  ...      SF  NaN  NaN
#
# 0    EL   CW   SC  CWC  FM                     Name Goals
# 74  NaN  NaN  NaN  NaN  R4              Kerry Dixon    12
# 75  NaN  NaN  NaN  NaN  R3             Gordon Durie    20
# 76  NaN  NaN  NaN  NaN  R3              Kerry Dixon    28
# 77  NaN  NaN  NaN  NaN   W              Kerry Dixon    25
# 78  NaN  NaN  NaN  NaN  R3  Kerry DixonGordon Durie    15
#
# [5 rows x 21 columns]

# %%
city[city['Season']=='1986-87']
# Out:
# 0     Season Division (Tier)   P  W   D   L   F   A Pts   Pos FA Cup  \
# 108  1986-87         Div 1    42  8  15  19  36  57  39  21st     R3
#
# 0   League Cup    Europe / Other Europe / Other Top scorer[A] Goals
# 108         R3  Full Members Cup             R4   Imre Varadi     9

# %%
city = city[107:]
city.head()
# Out:
# 0     Season Division (Tier)   P   W   D   L   F   A Pts   Pos FA Cup  \
# 108  1986-87         Div 1    42   8  15  19  36  57  39  21st     R3
# 109  1987-88       Div 2 (2)  44  19   8  17  80  60  65   0th     QF
# 110  1988-89       Div 2 (2)  46  23  13  10  77  53  82   0th     R4
# 111  1989-90         Div 1    38  12  12  14  43  52  48  14th     R3
# 112  1990-91         Div 1    38  17  11  10  64  53  62   5th     R5
#
# 0   League Cup    Europe / Other Europe / Other Top scorer[A] Goals
# 108         R3  Full Members Cup             R4   Imre Varadi     9
# 109         QF  Full Members Cup             R2  Paul Stewart    27
# 110         R4  Full Members Cup             R2  Paul Moulden    17
# 111         R4  Full Members Cup             R2   Clive Allen    11
# 112         R3  Full Members Cup             R4   Niall Quinn    21

# %%
liverpool[liverpool['Season']=='1986-87']
# Out:
# 0    Season    Division   P   W  D   L   F   A Pts  Pos FA Cup EFL Cup  \
# 87  1986-87  Division 1  42  23  8  11  72  42  77  2nd     R3      RU
#
# 0  Comm. Shield CL EL CWC Super Cup Club World Cup      Name Goals
# 87         W[H]  —  —   —         —              —  Ian Rush    40

# %%
liverpool = liverpool[86:]
liverpool.head()
# Out:
# 0    Season    Division   P   W   D   L   F   A Pts  Pos FA Cup EFL Cup  \
# 87  1986-87  Division 1  42  23   8  11  72  42  77  2nd     R3      RU
# 88  1987-88  Division 1  40  26  12   2  87  24  90  1st     RU      R3
# 89  1988-89  Division 1  38  22  10   6  65  28  76  2nd      W      R4
# 90  1989-90  Division 1  38  23  10   5  78  37  79  1st     SF      R3
# 91  1990-91  Division 1  38  23   7   8  77  40  76  2nd     R5      R3
#
# 0  Comm. Shield CL EL CWC Super Cup Club World Cup              Name Goals
# 87         W[H]  —  —   —         —              —          Ian Rush    40
# 88            —  —  —   —         —              —  John Aldridge[J]  29 ♦
# 89            W  —  —   —         —              —     John Aldridge    31
# 90            W  —  —   —         —              —       John Barnes    28
# 91         W[H]  —  —   —         —              —          Ian Rush    26

# %%
united[united['Season']=='1986-87']
# Out:
#      Season Division   P   W   D   L   F   A Pts   Pos FA Cup LeagueCup  \
# 93  1986-87    Div 1  42  14  14  14  52  45  56  11th     R4        R3
#
#    CommunityShield UEFAFIFA             Name Goals
# 93             NaN      NaN  Peter Davenport    16

# %%
united = united[92:]
united.head()
# Out:
#      Season Division   P   W   D   L   F   A     Pts   Pos   FA Cup  \
# 93  1986-87    Div 1  42  14  14  14  52  45      56  11th       R4
# 94  1987-88    Div 1  40  23  12   5  71  38      81   2nd       R5
# 95  1988-89    Div 1  38  13  12  13  45  35      51  11th       R6
# 96  1989-90    Div 1  38  13   9  16  46  47      48  13th  Winners
# 97  1990-91    Div 1  38  16  12  10  58  45  59[26]   6th       R5
#
#      LeagueCup CommunityShield                    UEFAFIFA  \
# 93          R3             NaN                         NaN
# 94          R5             NaN                         NaN
# 95          R3             NaN                         NaN
# 96          R3             NaN                         NaN
# 97  Runners-up      Shared[22]  Cup Winners' Cup - Winners
#
#                         Name Goals
# 93           Peter Davenport    16
# 94             Brian McClair    31
# 95  Mark HughesBrian McClair    16
# 96               Mark Hughes    15
# ...

# %%
liverpool.drop(120, inplace=True)
liverpool.tail()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# 0     Season Division   P   W   D   L   F   A Pts  Pos FA Cup EFL Cup  \
# 115  2014-15       PL  38  18   8  12  52  48  62  6th     SF      SF
# 116  2015-16       PL  38  16  12  10  63  50  60  8th     R4      RU
# 117  2016-17       PL  38  22  10   6  78  42  76  4th     R4      SF
# 118  2017-18       PL  38  21  12   5  84  38  75  4th     R4      R3
# 119  2018-19       PL  38  30   7   1  89  22  97  2nd     R3      R3
#
# 0   Comm. Shield      CL   EL CWC Super Cup Club World Cup               Name  \
# 115            —  Grp[M]  R32   —         —              —     Steven Gerrard
# 116            —       —   RU   —         —              —   Daniel Sturridge
# ...

# %%
arsenal = arsenal[['Season', 'Pos']]
arsenal['Pos'] = arsenal['Pos'].str.replace(pat='st', repl='')
arsenal['Pos'] = arsenal['Pos'].str.replace(pat='nd', repl='')
arsenal['Pos'] = arsenal['Pos'].str.replace(pat='rd', repl='')
arsenal['Pos'] = arsenal['Pos'].str.replace(pat='0th', repl='22')
arsenal['Pos'] = arsenal['Pos'].str.replace(pat='th', repl='')
arsenal['Pos'] = arsenal['Pos'].str.replace(pat='122', repl='10')

arsenal['Pos'] = arsenal['Pos'].astype(float)
arsenal.reset_index(inplace=True)
arsenal.drop('index',axis=1, inplace=True)

chelsea = chelsea[['Season', 'Pos']]
chelsea['Pos'] = chelsea['Pos'].str.replace(pat='st', repl='')
chelsea['Pos'] = chelsea['Pos'].str.replace(pat='nd', repl='')
chelsea['Pos'] = chelsea['Pos'].str.replace(pat='rd', repl='')
chelsea['Pos'] = chelsea['Pos'].str.replace(pat='0th', repl='22')
chelsea['Pos'] = chelsea['Pos'].str.replace(pat='th', repl='')
chelsea['Pos'] = chelsea['Pos'].str.replace(pat='122', repl='10')
chelsea['Pos'] = chelsea['Pos'].astype(float)
chelsea.reset_index(inplace=True)
chelsea.drop('index',axis=1, inplace=True)


city = city[['Season', 'Pos']]
city['Pos'] = city['Pos'].str.replace(pat='st', repl='')
city['Pos'] = city['Pos'].str.replace(pat='nd', repl='')
city['Pos'] = city['Pos'].str.replace(pat='rd', repl='')
city['Pos'] = city['Pos'].str.replace(pat='0th', repl='22')
city['Pos'] = city['Pos'].str.replace(pat='th', repl='')
city['Pos'] = city['Pos'].str.replace(pat='122', repl='10')
city['Pos'] = city['Pos'].astype(float)
city.reset_index(inplace=True)
city.drop('index',axis=1, inplace=True)


liverpool = liverpool[['Season', 'Pos']]
liverpool['Pos'] = liverpool['Pos'].str.replace(pat='st', repl='')
liverpool['Pos'] = liverpool['Pos'].str.replace(pat='nd', repl='')
liverpool['Pos'] = liverpool['Pos'].str.replace(pat='rd', repl='')
liverpool['Pos'] = liverpool['Pos'].str.replace(pat='0th', repl='22')
liverpool['Pos'] = liverpool['Pos'].str.replace(pat='th', repl='')
liverpool['Pos'] = liverpool['Pos'].str.replace(pat='122', repl='10')
liverpool['Pos'] = liverpool['Pos'].astype(float)
liverpool.reset_index(inplace=True)
liverpool.drop('index',axis=1, inplace=True)

united = united[['Season', 'Pos']]
united['Pos'] = united['Pos'].str.replace(pat='st', repl='')
united['Pos'] = united['Pos'].str.replace(pat='nd', repl='')
united['Pos'] = united['Pos'].str.replace(pat='rd', repl='')
united['Pos'] = united['Pos'].str.replace(pat='th', repl='')
united['Pos'] = united['Pos'].astype(float)
united.reset_index(inplace=True)
united.drop('index',axis=1, inplace=True)

# %%
city.drop([26,27,29,32,37], inplace=True)
city.reset_index(inplace=True)
city.drop('index',axis=1, inplace=True)
# Duplicates

# %%
arsenal.shape, city.shape, chelsea.shape, liverpool.shape, united.shape
# Out:
# ((33, 2), (33, 2), (33, 2), (33, 2), (33, 2))

# %%
# %matplotlib notebook
import seaborn as sns
#sns.set()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(arsenal['Pos'], 'pink')
plt.plot(chelsea['Pos'], 'darkblue')
plt.plot(city['Pos'], 'lightblue')
plt.plot(liverpool['Pos'], 'orange')
plt.plot(united['Pos'], 'red')

plt.gca().invert_yaxis()
plt.axvline(x=26)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.legend(['Arsenal', 'Chelsea', 'Manchester City', 'Liverpool', 'Manchester United'],ncol=2, loc='lower right');

# %%
# Too cluttered.... Have to change

# %%
plt.style.use('seaborn-white')
#plt.style.use('ggplot')
#plt.style.available

# %%
fig, axs = plt.subplots(4, 1, sharex=True, sharey=True, figsize=(12,25))
fig.tight_layout(rect=[0.02, 0.6, 1, 0.95])

fig.suptitle('Comparison Between the Final League Position of Manchester United with the Rest of the "Premier League Top 5" \n(Before and After the Retirement of Sir Alex Ferguson from Managing Manchester United)\n*Value of 22 points denotes Team was Relegated from the Premier League*')

axs[0].plot(united['Pos'], 'red')
axs[0].plot(arsenal['Pos'], 'orange')
axs[0].set_ylim([0,22])
axs[0].axvline(x=26,color='black', alpha=0.6)
axs[0].text(x=26.3,y=13, s='<- Sir Alex Ferguson Retires', alpha=0.7, color='black')
axs[0].legend(['Manchester United', 'Arsenal'], frameon=True, loc='lower right', fontsize='medium')
#axs[0].set_facecolor('gray', alpha=0.6)
axs[0].grid(color='gray', alpha=0.2)
axs[0].set_ylabel('Total Points Won(At the End of the Season)')
#axs[0].spines['right'].set_visible(True)

axs[1].plot(united['Pos'], 'red')
axs[1].plot(chelsea['Pos'], 'blue')
axs[1].set_ylim([0,22])
axs[1].axvline(x=26,color='black',alpha=0.6)
axs[1].text(x=26.3,y=13, s='<- Sir Alex Ferguson Retires', alpha=0.7, color='black')
axs[1].grid(color='gray', alpha=0.2)
axs[1].legend(['Manchester United', 'Chelsea'], frameon=True, loc='lower right', fontsize='medium')
axs[1].set_ylabel('Total Points Won(At the End of the Season)')


axs[2].plot(united['Pos'], 'red')
axs[2].plot(city['Pos'], '#72bcd4')
axs[2].set_ylim([0,22])
axs[2].axvline(x=26,color='black')
axs[2].text(x=26.3,y=13, s='<- Sir Alex Ferguson Retires', alpha=0.7, color='black')
axs[2].grid(color='gray', alpha=0.2)
axs[2].legend(['Manchester United', 'Manchester City'], frameon=True, loc='lower right', fontsize='medium')
axs[2].set_ylabel('Total Points Won(At the End of the Season)')

axs[3].plot(united['Pos'], 'red')
axs[3].plot(liverpool['Pos'], 'green')
axs[3].set_ylim([0,22])
axs[3].axvline(x=26, color='black', alpha=0.6)
axs[3].text(x=26.3,y=13, s='<- Sir Alex Ferguson Retires', alpha=0.7, color='black')
axs[3].grid(color='gray', alpha=0.2)
axs[3].legend(['Manchester United', 'Liverpool'], frameon=True, loc='lower right', fontsize='medium')
axs[3].set_ylabel('Total Points Won(At the End of the Season)')


plt.gca().invert_yaxis()

plt.xticks(arsenal.index, arsenal['Season'], rotation='vertical')
plt.yticks(list(range(0,23)))
plt.subplots_adjust(bottom=0.09)



for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels():
        label.set_visible(True)
        label.set_rotation('vertical')
        
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
plt.savefig('Ass4.jpg')

# %%
'''
plt.figure()

axs[0].plot(united['Pos'], 'red')
axs[0].plot(arsenal['Pos'], 'gold')
axs[0].set_ylim([0,22])
axs[0].axvline(x=26,color='black')
axs[0].legend(['Manchester United', 'Arsenal'], frameon=True)
#axs[0].set_facecolor('white')
#axs[0].grid(color='gray', alpha=0.5)
#axs[0].spines['right'].set_visible(True)

axs[1].plot(united['Pos'], 'red')
axs[1].plot(chelsea['Pos'], 'darkblue')
axs[1].set_ylim([0,22])
axs[1].axvline(x=26,color='black')
axs[1].legend(['Manchester United', 'Chelsea'], frameon=True)


axs[2].plot(united['Pos'], 'red')
axs[2].plot(city['Pos'], 'lightblue')
axs[2].set_ylim([0,22])
axs[2].axvline(x=26,color='black')
axs[2].legend(['Manchester United', 'Manchester City'], frameon=True)


axs[3].plot(united['Pos'], 'red')
axs[3].plot(liverpool['Pos'], 'brown')
axs[3].set_ylim([0,22])
axs[3].axvline(x=26, color='black')
axs[3].legend(['Manchester United', 'Liverpool'], frameon=True)


plt.gca().invert_yaxis()

plt.xticks(arsenal.index, arsenal['Season'], rotation='vertical')
plt.yticks(list(range(0,23)))
plt.subplots_adjust(hspace=0.3,bottom=0.09)



for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels():
        label.set_visible(True)
        label.set_rotation('vertical')
        
fig.show()'''
# Out:
# "\nplt.figure()\n\naxs[0].plot(united['Pos'], 'red')\naxs[0].plot(arsenal['Pos'], 'gold')\naxs[0].set_ylim([0,22])\naxs[0].axvline(x=26,color='black')\naxs[0].legend(['Manchester United', 'Arsenal'], frameon=True)\n#axs[0].set_facecolor('white')\n#axs[0].grid(color='gray', alpha=0.5)\n#axs[0].spines['right'].set_visible(True)\n\naxs[1].plot(united['Pos'], 'red')\naxs[1].plot(chelsea['Pos'], 'darkblue')\naxs[1].set_ylim([0,22])\naxs[1].axvline(x=26,color='black')\naxs[1].legend(['Manchester United', 'Chelsea'], frameon=True)\n\n\naxs[2].plot(united['Pos'], 'red')\naxs[2].plot(city['Pos'], 'lightblue')\naxs[2].set_ylim([0,22])\naxs[2].axvline(x=26,color='black')\naxs[2].legend(['Manchester United', 'Manchester City'], frameon=True)\n\n\naxs[3].plot(united['Pos'], 'red')\naxs[3].plot(liverpool['Pos'], 'brown')\naxs[3].set_ylim([0,22])\naxs[3].axvline(x=26, color='black')\naxs[3].legend(['Manchester United', 'Liverpool'], frameon=True)\n\n\nplt.gca().invert_yaxis()\n\nplt.xticks(arsenal.
# ...

# %%
'''arsenal = arsenal[['Season', 'Pts']]
city = city[['Season', 'Pts']]
chelsea = chelsea[['Season', 'Pts']]
liverpool = liverpool[['Season', 'Pts']]
united = united[['Season', 'Pts']]


united['Pts'] = united['Pts'].str.replace(pat='\[26\]', repl='')
arsenal['Pts'] = arsenal['Pts'].str.replace(pat='\[r\]', repl='')


arsenal.reset_index(inplace=True)
arsenal.drop('index',axis=1, inplace=True)

chelsea.reset_index(inplace=True)
chelsea.drop('index',axis=1, inplace=True)
city.reset_index(inplace=True)
city.drop('index',axis=1, inplace=True)
liverpool.reset_index(inplace=True)
liverpool.drop('index',axis=1, inplace=True)
united.reset_index(inplace=True)
united.drop('index',axis=1, inplace=True)

arsenal['Pts'] = arsenal['Pts'].astype(float)

chelsea['Pts'] = chelsea['Pts'].astype(float)

city['Pts'] = city['Pts'].astype(float)

liverpool['Pts'] = liverpool['Pts'].astype(float)

united['Pts'] = united['Pts'].astype(float)


city.drop([26,27,29,32,37], inplace=True)
arsenal.shape, city.shape, chelsea.shape, liverpool.shape, united.shape

plt.figure()
plt.plot(arsenal['Pts'], 'darkblue')
plt.plot(chelsea['Pts'], 'green')
plt.plot(city['Pts'], 'lightblue')
plt.plot(liverpool['Pts'], 'orange')
plt.plot(united['Pts'], 'red')

#plt.gca().invert_yaxis()
plt.axvline(x=26)'''
# Out:
# "arsenal = arsenal[['Season', 'Pts']]\ncity = city[['Season', 'Pts']]\nchelsea = chelsea[['Season', 'Pts']]\nliverpool = liverpool[['Season', 'Pts']]\nunited = united[['Season', 'Pts']]\n\n\nunited['Pts'] = united['Pts'].str.replace(pat='\\[26\\]', repl='')\narsenal['Pts'] = arsenal['Pts'].str.replace(pat='\\[r\\]', repl='')\n\n\narsenal.reset_index(inplace=True)\narsenal.drop('index',axis=1, inplace=True)\n\nchelsea.reset_index(inplace=True)\nchelsea.drop('index',axis=1, inplace=True)\ncity.reset_index(inplace=True)\ncity.drop('index',axis=1, inplace=True)\nliverpool.reset_index(inplace=True)\nliverpool.drop('index',axis=1, inplace=True)\nunited.reset_index(inplace=True)\nunited.drop('index',axis=1, inplace=True)\n\narsenal['Pts'] = arsenal['Pts'].astype(float)\n\nchelsea['Pts'] = chelsea['Pts'].astype(float)\n\ncity['Pts'] = city['Pts'].astype(float)\n\nliverpool['Pts'] = liverpool['Pts'].astype(float)\n\nunited['Pts'] = united['Pts'].astype(float)\n\n\ncity.drop([26,27,29,32,37], 
# ...
